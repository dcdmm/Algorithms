# %% [markdown]
# <img src='../../Other/img/grey.JPG'>

# %%
def moves_ins(n, forward):
    if n == 0: 
        return None
    moves_ins(n-1, True)
    print("enter ", n) if forward else print("exit  ", n)
    moves_ins(n-1, False)

# %%
moves_ins(4, True) # 开始肯定为True,即enter
# Out:
# enter  1
# enter  2
# exit   1
# enter  3
# enter  1
# exit   2
# exit   1
# enter  4
# enter  1
# enter  2
# exit   1
# exit   3
# enter  1
# exit   2
# exit   1
